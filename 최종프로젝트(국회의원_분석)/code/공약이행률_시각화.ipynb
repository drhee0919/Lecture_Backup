# %%
import matplotlib as mpl  # 기본 설정 만지는 용도
import matplotlib.pyplot as plt  # 그래프 그리는 용도
import matplotlib.font_manager as fm  # 폰트 관련 용도

# 글꼴사용
path = 'C:\\Users\\student\\AppData\\Local\\Microsoft\\Windows\\Fonts\\NanumSquare_acL.ttf'  
font_name = fm.FontProperties(fname=path, size=10).get_name()
print(font_name)
plt.rc('font', family=font_name)
# Out:
# NanumSquare_ac

# %%
import pandas as pd 
import numpy as np 

raw_data = pd.read_excel('./data/manifesto/manifesto_result.xlsx',
                         sheet_name='Sheet2',
                         encoding='UTF-8')
display(raw_data)
# Out:
#    국회의원  국정공약  지역공약  입법공약  재정공약  총 공약수  완료  추진중  보류  폐기  기타
# 0   강병원    10    14     6    11     24  13   11   0   0   0
# 1   고용진     4    10     0     0     14   6    5   0   0   3
# 2   금태섭     3    22     0    18     22   0   21   1   0   0
# 3   기동민     0     9     0     9      9   2    7   0   0   0
# 4   김병기    11    22     8    25     33  24    9   0   0   0
# 5   김성식     4    10     4     1     17   9    8   0   0   0
# 6   김성환    10     9     9     9     19   7   12   0   0   0
# 7   김영호     0    12     0     0      0   1    8   0   0   0
# 8   김용태     3    11     5     6     11   7    4   0   0   0
# 9   나경원     0    71     0    71     72  45   26   0   0   1
# 10  남인순    43    31    22    41     71  19   35  14   3   0
# 11  노웅래    15    34    14    35     49  29   14   5   1   0
# 12  민병두     0    27     7    17     34   5   26   3   0   0
# 13  박성중     7    22     8    19     29   8   18   3   0   0
# 14  박영선     1    34     1    32     36  23   10   0   2   1
# ...

# %%
# 이행률 측정에 필요한 총공약수, 완료/추진중/보류/폐기/기타 공약수 로딩하기 
df = raw_data[['국회의원','총 공약수','완료','추진중','보류','폐기','기타']]
display(df)

'''
pie_list=list()
for n in len(df):
    p = pd.Dataframe(df.ix[n])
    p = p.transpose()
    print(p)
    pie_list.append(p)

print(pie_list)
'''
'''
p1 = pd.DataFrame(df.ix[0])
p1 = p1.transpose()
display(p1)
'''
#display(p1.transpose())
#display(p1.reset_index(level=[None], inplace = True))
# Out:
#    국회의원  총 공약수  완료  추진중  보류  폐기  기타
# 0   강병원     24  13   11   0   0   0
# 1   고용진     14   6    5   0   0   3
# 2   금태섭     22   0   21   1   0   0
# 3   기동민      9   2    7   0   0   0
# 4   김병기     33  24    9   0   0   0
# 5   김성식     17   9    8   0   0   0
# 6   김성환     19   7   12   0   0   0
# 7   김영호      0   1    8   0   0   0
# 8   김용태     11   7    4   0   0   0
# 9   나경원     72  45   26   0   0   1
# 10  남인순     71  19   35  14   3   0
# 11  노웅래     49  29   14   5   1   0
# 12  민병두     34   5   26   3   0   0
# 13  박성중     29   8   18   3   0   0
# 14  박영선     36  23   10   0   2   1
# 15  박용진     27  24    3   0   0   0
# 16  박인숙     40  15   17   1   3   4
# 17  박주민     37   6   28   3   0   0
# 18  박홍근     38   3   34   0   1   0
# 19  서영교     25  23    2   0   0   0
# 20  손혜원     58  14   34   8   2   0
# 21  신경민     48  23   21   2   2   0
# 22  심재권     63  60    3   0   0   0
# 23  안규백     55  39   16   0   0   0
# 24  오신환     37  27   10   0   0   0
# ...

# %%
# 국회의원 별로 세부 df 만들기
p0 = pd.DataFrame(df.ix[0]).transpose()
p1 = pd.DataFrame(df.ix[1]).transpose()
p2 = pd.DataFrame(df.ix[2]).transpose()
p3 = pd.DataFrame(df.ix[3]).transpose()
p4 = pd.DataFrame(df.ix[4]).transpose()
p5 = pd.DataFrame(df.ix[5]).transpose()
p6 = pd.DataFrame(df.ix[6]).transpose()
p7 = pd.DataFrame(df.ix[7]).transpose()
p8 = pd.DataFrame(df.ix[8]).transpose()
p9 = pd.DataFrame(df.ix[9]).transpose()
p10 = pd.DataFrame(df.ix[10]).transpose()
p11 = pd.DataFrame(df.ix[11]).transpose()
p12 = pd.DataFrame(df.ix[12]).transpose()
p13 = pd.DataFrame(df.ix[13]).transpose()
p14 = pd.DataFrame(df.ix[14]).transpose()
p15 = pd.DataFrame(df.ix[15]).transpose()
p16 = pd.DataFrame(df.ix[16]).transpose()
p17 = pd.DataFrame(df.ix[17]).transpose()
p18 = pd.DataFrame(df.ix[18]).transpose()
p19 = pd.DataFrame(df.ix[19]).transpose()
p20 = pd.DataFrame(df.ix[20]).transpose()
p21 = pd.DataFrame(df.ix[21]).transpose()
p22 = pd.DataFrame(df.ix[22]).transpose()
p23 = pd.DataFrame(df.ix[23]).transpose()
p24 = pd.DataFrame(df.ix[24]).transpose()
p25 = pd.DataFrame(df.ix[25]).transpose()
p26 = pd.DataFrame(df.ix[26]).transpose()
p27 = pd.DataFrame(df.ix[27]).transpose()
p28 = pd.DataFrame(df.ix[28]).transpose()
p29 = pd.DataFrame(df.ix[29]).transpose()
p30 = pd.DataFrame(df.ix[30]).transpose()
p31 = pd.DataFrame(df.ix[31]).transpose()
p32 = pd.DataFrame(df.ix[32]).transpose()
p33 = pd.DataFrame(df.ix[33]).transpose()
p34 = pd.DataFrame(df.ix[34]).transpose()
p35 = pd.DataFrame(df.ix[35]).transpose()
p36 = pd.DataFrame(df.ix[36]).transpose()
p37 = pd.DataFrame(df.ix[37]).transpose()
p38 = pd.DataFrame(df.ix[38]).transpose()
p39 = pd.DataFrame(df.ix[39]).transpose()
p40 = pd.DataFrame(df.ix[40]).transpose()
# Out:
# C:\Users\student\Anaconda3\envs\cpu_env\lib\site-packages\ipykernel_launcher.py:2: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#
# C:\Users\student\Anaconda3\envs\cpu_env\lib\site-packages\ipykernel_launcher.py:3: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\student\Anaconda3\envs\cpu_env\lib\site-packages\ipykernel_launcher.py:4: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# ...

# %%
# 아시발 아니네 다시 행렬 순서바꿈 
p0 = pd.DataFrame(df.ix[0])
p1 = pd.DataFrame(df.ix[1])
p2 = pd.DataFrame(df.ix[2])
p3 = pd.DataFrame(df.ix[3])
p4 = pd.DataFrame(df.ix[4])
p5 = pd.DataFrame(df.ix[5])
p6 = pd.DataFrame(df.ix[6])
p7 = pd.DataFrame(df.ix[7])
p8 = pd.DataFrame(df.ix[8])
p9 = pd.DataFrame(df.ix[9])
p10 = pd.DataFrame(df.ix[10])
p11 = pd.DataFrame(df.ix[11])
p12 = pd.DataFrame(df.ix[12])
p13 = pd.DataFrame(df.ix[13])
p14 = pd.DataFrame(df.ix[14])
p15 = pd.DataFrame(df.ix[15])
p16 = pd.DataFrame(df.ix[16])
p17 = pd.DataFrame(df.ix[17])
p18 = pd.DataFrame(df.ix[18])
p19 = pd.DataFrame(df.ix[19])
p20 = pd.DataFrame(df.ix[20])
p21 = pd.DataFrame(df.ix[21])
p22 = pd.DataFrame(df.ix[22])
p23 = pd.DataFrame(df.ix[23])
p24 = pd.DataFrame(df.ix[24])
p25 = pd.DataFrame(df.ix[25])
p26 = pd.DataFrame(df.ix[26])
p27 = pd.DataFrame(df.ix[27])
p28 = pd.DataFrame(df.ix[28])
p29 = pd.DataFrame(df.ix[29])
p30 = pd.DataFrame(df.ix[30])
p31 = pd.DataFrame(df.ix[31])
p32 = pd.DataFrame(df.ix[32])
p33 = pd.DataFrame(df.ix[33])
p34 = pd.DataFrame(df.ix[34])
p35 = pd.DataFrame(df.ix[35])
p36 = pd.DataFrame(df.ix[36])
p37 = pd.DataFrame(df.ix[37])
p38 = pd.DataFrame(df.ix[38])
p39 = pd.DataFrame(df.ix[39])
p40 = pd.DataFrame(df.ix[40])
# Out:
# C:\Users\student\Anaconda3\envs\cpu_env\lib\site-packages\ipykernel_launcher.py:2: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#
# C:\Users\student\Anaconda3\envs\cpu_env\lib\site-packages\ipykernel_launcher.py:3: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\student\Anaconda3\envs\cpu_env\lib\site-packages\ipykernel_launcher.py:4: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# ...

# %%
# 인덱스 초기화 
p0 = p0.reset_index()
p1 = p1.reset_index()
p2 = p2.reset_index()
p3 = p3.reset_index()
p4 = p4.reset_index()
p5 = p5.reset_index()
p6 = p6.reset_index()
p7 = p7.reset_index()
p8 = p8.reset_index()
p9 = p9.reset_index()
p10 = p10.reset_index()
p11 = p11.reset_index()
p12 = p12.reset_index()
p13 = p13.reset_index()
p14 = p14.reset_index()
p15 = p15.reset_index()
p16 = p16.reset_index()
p17 = p17.reset_index()
p18 = p18.reset_index()
p19 = p19.reset_index()
p20 = p20.reset_index()
p21 = p21.reset_index()
p22 = p22.reset_index()
p23 = p23.reset_index()
p24 = p24.reset_index()
p25 = p25.reset_index()
p26 = p26.reset_index()
p27 = p27.reset_index()
p28 = p28.reset_index()
p29 = p29.reset_index() 
p30 = p30.reset_index()
p31 = p31.reset_index()
p32 = p32.reset_index()
p33 = p33.reset_index()
p34 = p34.reset_index()
p35 = p35.reset_index()
p36 = p36.reset_index()
p37 = p37.reset_index()
p38 = p38.reset_index()
p39 = p39.reset_index()
p40 = p40.reset_index()

# %%
#칼럼명 수정 
p0.columns = [p0.iloc[0, 1], "이행내역"] 
p1.columns = [p1.iloc[0, 1], "이행내역"] 
p2.columns = [p2.iloc[0, 1], "이행내역"] 
p3.columns = [p3.iloc[0, 1], "이행내역"]
p4.columns = [p4.iloc[0, 1], "이행내역"] 
p5.columns = [p5.iloc[0, 1], "이행내역"] 
p6.columns = [p6.iloc[0, 1], "이행내역"] 
p7.columns = [p7.iloc[0, 1], "이행내역"] 
p8.columns = [p8.iloc[0, 1], "이행내역"] 
p9.columns = [p9.iloc[0, 1], "이행내역"] 
p10.columns = [p10.iloc[0, 1], "이행내역"]
p11.columns = [p11.iloc[0, 1], "이행내역"]
p12.columns = [p12.iloc[0, 1], "이행내역"]
p13.columns = [p13.iloc[0, 1], "이행내역"]
p14.columns = [p14.iloc[0, 1], "이행내역"]
p15.columns = [p15.iloc[0, 1], "이행내역"]
p16.columns = [p16.iloc[0, 1], "이행내역"]
p17.columns = [p17.iloc[0, 1], "이행내역"]
p18.columns = [p18.iloc[0, 1], "이행내역"]
p19.columns = [p19.iloc[0, 1], "이행내역"]
p20.columns = [p20.iloc[0, 1], "이행내역"]
p21.columns = [p21.iloc[0, 1], "이행내역"]
p22.columns = [p22.iloc[0, 1], "이행내역"]
p23.columns = [p23.iloc[0, 1], "이행내역"]
p24.columns = [p24.iloc[0, 1], "이행내역"]
p25.columns = [p25.iloc[0, 1], "이행내역"]
p26.columns = [p26.iloc[0, 1], "이행내역"]
p27.columns = [p27.iloc[0, 1], "이행내역"]
p28.columns = [p28.iloc[0, 1], "이행내역"]
p29.columns = [p29.iloc[0, 1], "이행내역"]
p30.columns = [p30.iloc[0, 1], "이행내역"]
p31.columns = [p31.iloc[0, 1], "이행내역"]
p32.columns = [p32.iloc[0, 1], "이행내역"]
p33.columns = [p33.iloc[0, 1], "이행내역"]
p34.columns = [p34.iloc[0, 1], "이행내역"]
p35.columns = [p35.iloc[0, 1], "이행내역"]
p36.columns = [p36.iloc[0, 1], "이행내역"]
p37.columns = [p37.iloc[0, 1], "이행내역"]
p38.columns = [p38.iloc[0, 1], "이행내역"]
p39.columns = [p39.iloc[0, 1], "이행내역"]
p40.columns = [p40.iloc[0, 1], "이행내역"]

# %%
display(p0)
# Out:
#      강병원 이행내역
# 0   국회의원  강병원
# 1  총 공약수   24
# 2     완료   13
# 3    추진중   11
# 4     보류    0
# 5     폐기    0
# 6     기타    0

# %%
#첫째행 날려버리기
p0=p0.drop(0,0)
p1=p1.drop(0,0)
p2=p2.drop(0,0)
p3=p3.drop(0,0)
p4=p4.drop(0,0)
p5=p5.drop(0,0)
p6=p6.drop(0,0)
p7=p7.drop(0,0)
p8=p8.drop(0,0)
p9=p9.drop(0,0)
p10=p10.drop(0,0)
p11=p11.drop(0,0)
p12=p12.drop(0,0)
p13=p13.drop(0,0)
p14=p14.drop(0,0)
p15=p15.drop(0,0)
p16=p16.drop(0,0)
p17=p17.drop(0,0)
p18=p18.drop(0,0)
p19=p19.drop(0,0)
p20=p20.drop(0,0)
p21=p21.drop(0,0)
p22=p22.drop(0,0)
p23=p23.drop(0,0)
p24=p24.drop(0,0)
p25=p25.drop(0,0)
p26=p26.drop(0,0)
p27=p27.drop(0,0)
p28=p28.drop(0,0)
p29=p29.drop(0,0)
p30=p30.drop(0,0)
p31=p31.drop(0,0)
p32=p32.drop(0,0)
p33=p33.drop(0,0)
p34=p34.drop(0,0)
p35=p35.drop(0,0)
p36=p36.drop(0,0)
p37=p37.drop(0,0)
p38=p38.drop(0,0)
p39=p39.drop(0,0)
p40=p40.drop(0,0)

# %%
display(p13)
# Out:
#      박성중 이행내역
# 1  총 공약수   29
# 2     완료    8
# 3    추진중   18
# 4     보류    3
# 5     폐기    0
# 6     기타    0

# %%
'''
## 긍 부정 개수 파악 및 pie chart 그리기 
print(df['결과'].value_counts()["['1']"])
print(df['결과'].value_counts()["['0']"])
'''

#차트 크기 설정
plt.rcParams['figure.figsize'] = [12, 8]

#정보 관련 변수 설정
group_names = ['완료', '추진중','보류','폐기','기타']

group_sizes = [p0['완료'], p0['추진중'],p0['보류'],p0['폐기'],p0['기타']]

# group_colors = ['gold', 'silver']

group_explodes = (0.1, 0, 0, 0, 0) # explode 1st slice


# Pie chart

plt.pie(group_sizes, 

        explode=group_explodes, 

        labels=group_names, 

        #colors=group_colors, 

        autopct='%1.2f%%', # second decimal place

        shadow=True, 

        startangle=90,

        textprops={'fontsize': 20, 'color': 'Black'}) # text font size

plt.axis('equal') #  equal length of X and Y axis

plt.title('공약이행도',color='Black', fontsize=30)

plt.show()
# Out:
# C:\Users\student\Anaconda3\envs\cpu_env\lib\site-packages\ipykernel_launcher.py:36: MatplotlibDeprecationWarning: Non-1D inputs to pie() are currently squeeze()d, but this behavior is deprecated since 3.1 and will be removed in 3.3; pass a 1D array instead.

# %%
# 0% 항목에 대한 파이차트가 너무 구데기여서 바차트로 선회 

import pickle
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

#df = pd.read_pickle("apt_tot.pkl")

'''
#나눔고딕bold 폰트 사용 
import matplotlib.font_manager as fm
fm.get_fontconfig_fonts()
font_location = 'C:\\Users\\student\\AppData\\Local\\Microsoft\\Windows\\Fonts\\NanumBarunGothicBold.ttf'
font_name = fm.FontProperties(fname=font_location).get_name()
plt.rc('font', family=font_name)
'''
plt.xticks(rotation = 45 )
sns.barplot(x="국회의원", y="총 공약수", data=df)
#plt.show

# %%
plt.xticks(rotation = 45 )
sns.barplot(x="국회의원", y="완료", data=df)

# %%
plt.xticks(rotation = 45 )
sns.barplot(data=df,
            x="국회의원",
            y="완료",
            hue="총 공약수")

# %%
# 국회의원 별로 그려보기 
plt.xticks(rotation = 45 )
sns.barplot(x="강병원", y="이행내역", data=p0)

# %%
plt.xticks(rotation = 45 )
sns.barplot(x="고용진", y="이행내역", data=p1)

# %%
# 결과물 자동저장하기
# Out:
# 고용진
